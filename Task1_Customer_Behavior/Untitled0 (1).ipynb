# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/ecommerce_customer_data_large.csv')

# %%
df.head()
# Out:
#    Customer ID        Purchase Date Product Category  Product Price  Quantity  \
# 0        44605  2023-05-03 21:30:02             Home            177         1
# 1        44605  2021-05-16 13:57:44      Electronics            174         3
# 2        44605  2020-07-13 06:16:57            Books            413         1
# 3        44605  2023-01-17 13:14:36      Electronics            396         3
# 4        44605  2021-05-01 11:29:27            Books            259         4
#
#    Total Purchase Amount Payment Method  Customer Age  Returns Customer Name  \
# 0                   2427         PayPal            31      1.0   John Rivera
# 1                   2448         PayPal            31      1.0   John Rivera
# 2                   2345    Credit Card            31      1.0   John Rivera
# 3                    937           Cash            31      0.0   John Rivera
# 4                   2598         PayPal            31      1.0   John Rivera
#
#    Age  Gender  Churn
# 0   31  Female      0
# 1   31  Female      0
# 2   31  Female      0
# 3   31  Female      0
# 4   31  Female      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Customer ID            250000 non-null  int64
#  1   Purchase Date          250000 non-null  object
#  2   Product Category       250000 non-null  object
#  3   Product Price          250000 non-null  int64
#  4   Quantity               250000 non-null  int64
#  5   Total Purchase Amount  250000 non-null  int64
#  6   Payment Method         250000 non-null  object
#  7   Customer Age           250000 non-null  int64
#  8   Returns                202618 non-null  float64
#  9   Customer Name          250000 non-null  object
#  10  Age                    250000 non-null  int64
#  11  Gender                 250000 non-null  object
#  12  Churn                  250000 non-null  int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 24.8+ MB

# %%
df.isnull().sum()
# Out:
# Customer ID                  0
# Purchase Date                0
# Product Category             0
# Product Price                0
# Quantity                     0
# Total Purchase Amount        0
# Payment Method               0
# Customer Age                 0
# Returns                  47382
# Customer Name                0
# Age                          0
# Gender                       0
# Churn                        0
# dtype: int64

# %%
df.describe()
# Out:
#          Customer ID  Product Price       Quantity  Total Purchase Amount  \
# count  250000.000000  250000.000000  250000.000000          250000.000000
# mean    25017.632092     254.742724       3.004936            2725.385196
# std     14412.515718     141.738104       1.414737            1442.576095
# min         1.000000      10.000000       1.000000             100.000000
# 25%     12590.000000     132.000000       2.000000            1476.000000
# 50%     25011.000000     255.000000       3.000000            2725.000000
# 75%     37441.250000     377.000000       4.000000            3975.000000
# max     50000.000000     500.000000       5.000000            5350.000000
#
#         Customer Age        Returns            Age         Churn
# count  250000.000000  202618.000000  250000.000000  250000.00000
# mean       43.798276       0.500824      43.798276       0.20052
# std        15.364915       0.500001      15.364915       0.40039
# min        18.000000       0.000000      18.000000       0.00000
# 25%        30.000000       0.000000      30.000000       0.00000
# 50%        44.000000       1.000000      44.000000       0.00000
# 75%        57.000000       1.000000      57.000000       0.00000
# max        70.000000       1.000000      70.000000       1.00000

# %%
df.mean(numeric_only=True)
# Out:
# Customer ID              25017.632092
# Product Price              254.742724
# Quantity                     3.004936
# Total Purchase Amount     2725.385196
# Customer Age                43.798276
# Returns                      0.500824
# Age                         43.798276
# Churn                        0.200520
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# Customer ID              25011.0
# Product Price              255.0
# Quantity                     3.0
# Total Purchase Amount     2725.0
# Customer Age                44.0
# Returns                      1.0
# Age                         44.0
# Churn                        0.0
# dtype: float64

# %%
df.mode()
# Out:
#      Customer ID        Purchase Date Product Category  Product Price  \
# 0        48382.0  2020-01-01 15:49:02      Electronics          290.0
# 1            NaN  2020-01-06 22:26:24              NaN            NaN
# 2            NaN  2020-01-07 03:22:08              NaN            NaN
# 3            NaN  2020-01-12 02:11:29              NaN            NaN
# 4            NaN  2020-01-12 10:42:25              NaN            NaN
# ..           ...                  ...              ...            ...
# 267          NaN  2023-08-17 20:13:45              NaN            NaN
# 268          NaN  2023-08-21 18:09:49              NaN            NaN
# 269          NaN  2023-09-05 03:22:42              NaN            NaN
# 270          NaN  2023-09-05 09:42:43              NaN            NaN
# 271          NaN  2023-09-08 18:31:50              NaN            NaN
#
#      Quantity  Total Purchase Amount Payment Method  Customer Age  Returns  \
# 0         4.0                 2533.0    Credit Card          47.0      1.0
# 1         NaN                 4456.0            NaN           NaN      NaN
# 2         NaN                    NaN            NaN           NaN      NaN
# 3         NaN                    NaN            NaN           NaN      NaN
# 4         NaN                    NaN            NaN           NaN      NaN
# ..        ...                    ...            ...           ...      ...
# 267       NaN                    NaN            NaN           NaN      NaN
# 268       NaN                    NaN            NaN           NaN      NaN
# 269       NaN                    NaN            NaN           NaN      NaN
# 270       NaN                    NaN            NaN           NaN      NaN
# 271       NaN                    NaN            NaN           NaN      NaN
#
#        Customer Name   Age Gender  Churn
# 0    Michael Johnson  47.0   Male    0.0
# 1                NaN   NaN    NaN    NaN
# 2                NaN   NaN    NaN    NaN
# 3                NaN   NaN    NaN    NaN
# 4                NaN   NaN    NaN    NaN
# ..               ...   ...    ...    ...
# 267              NaN   NaN    NaN    NaN
# 268              NaN   NaN    NaN    NaN
# 269              NaN   NaN    NaN    NaN
# 270              NaN   NaN    NaN    NaN
# 271              NaN   NaN    NaN    NaN
#
# [272 rows x 13 columns]

# %%
df.drop_duplicates(inplace=True)

# %%
df.fillna(0, inplace=True)

# %%
df['Product Category'].value_counts().plot(kind='bar')
plt.title('Products Purchased by Category')
plt.xlabel('Category')
plt.ylabel('Count')
plt.show()

# %%
df['Gender'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Gender Distribution')
plt.ylabel('')
plt.show()

# %%
df['Age'].hist(bins=10)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Number of Customers')
plt.show()

# %%
df['Churn'].value_counts()
# Out:
# Churn
# 0    199870
# 1     50130
# Name: count, dtype: int64

# %%
df['Churn'].value_counts().plot(kind='bar')
plt.title('Customer Churn')
plt.xlabel('Churn')
plt.ylabel('Count')
plt.show()

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Customer ID            250000 non-null  int64
#  1   Purchase Date          250000 non-null  object
#  2   Product Category       250000 non-null  object
#  3   Product Price          250000 non-null  int64
#  4   Quantity               250000 non-null  int64
#  5   Total Purchase Amount  250000 non-null  int64
#  6   Payment Method         250000 non-null  object
#  7   Customer Age           250000 non-null  int64
#  8   Returns                250000 non-null  float64
#  9   Customer Name          250000 non-null  object
#  10  Age                    250000 non-null  int64
#  11  Gender                 250000 non-null  object
#  12  Churn                  250000 non-null  int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 24.8+ MB
# Customer ID              0
# Purchase Date            0
# Product Category         0
# Product Price            0
# Quantity                 0
# Total Purchase Amount    0
# Payment Method           0
# Customer Age             0
# Returns                  0
# Customer Name            0
# Age                      0
# Gender                   0
# Churn                    0
# dtype: int64

# %%
df['Purchase Date'] = pd.to_datetime(df['Purchase Date'])

# %%
snapshot_date = df['Purchase Date'].max()
print(snapshot_date)
# Out:
# 2023-09-13 18:42:49

# %%
rfm = df.groupby('Customer ID').agg({
    'Purchase Date': lambda x: (snapshot_date - x.max()).days,
    'Customer ID': 'count',
    'Total Purchase Amount': 'sum'
})

rfm.columns = ['Recency', 'Frequency', 'Monetary']

rfm.head()
# Out:
#              Recency  Frequency  Monetary
# Customer ID
# 1                288          3      6290
# 2                 72          6     16481
# 3                222          4      9423
# 4                441          5      7826
# 5                424          5      9769

# %%
rfm['R_score'] = pd.qcut(rfm['Recency'], 4, labels=[4,3,2,1])
rfm['F_score'] = pd.qcut(rfm['Frequency'].rank(method='first'), 4, labels=[1,2,3,4])
rfm['M_score'] = pd.qcut(rfm['Monetary'], 4, labels=[1,2,3,4])

rfm.head()
# Out:
#              Recency  Frequency  Monetary R_score F_score M_score
# Customer ID
# 1                288          3      6290       2       1       1
# 2                 72          6     16481       4       3       3
# 3                222          4      9423       2       2       2
# 4                441          5      7826       1       2       1
# 5                424          5      9769       1       2       2

# %%
rfm['Segment'] = (
    rfm['R_score'].astype(str)
    + rfm['F_score'].astype(str)
    + rfm['M_score'].astype(str)
)

rfm.head()
# Out:
#              Recency  Frequency  Monetary R_score F_score M_score Segment
# Customer ID
# 1                288          3      6290       2       1       1     211
# 2                 72          6     16481       4       3       3     433
# 3                222          4      9423       2       2       2     222
# 4                441          5      7826       1       2       1     121
# 5                424          5      9769       1       2       2     122

# %%
rfm['Segment'].value_counts().head(10)
# Out:
# Segment
# 111    4782
# 444    3520
# 344    2901
# 244    2126
# 211    2058
# 433    1723
# 333    1624
# 222    1621
# 233    1593
# 122    1561
# Name: count, dtype: int64

# %%
rfm['Segment'].value_counts().head(10).plot(kind='bar')
plt.title('Top Customer Segments')
plt.xlabel('Segment')
plt.ylabel('Number of Customers')
plt.show()

# %%
df['Product Category'].value_counts()
# Out:
# Product Category
# Electronics    62630
# Clothing       62581
# Home           62542
# Books          62247
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
df['Product Category'].value_counts().plot(kind='bar')
plt.title('Purchase Patterns by Category')
plt.xlabel('Product Category')
plt.ylabel('Number of Purchases')
plt.show()

# %%
df['Payment Method'].value_counts()
# Out:
# Payment Method
# Credit Card    83547
# PayPal         83441
# Cash           83012
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
df['Payment Method'].value_counts().plot(kind='bar')
plt.title('Payment Method Preference')
plt.xlabel('Payment Method')
plt.ylabel('Count')
plt.show()

# %%
df.groupby('Churn').size()
# Out:
# Churn
# 0    199870
# 1     50130
# dtype: int64

# %%
plt.figure(figsize=(6,4))
df.groupby('Churn').size().plot(kind='bar')
plt.title('Retention Trend')
plt.xlabel('Churn')
plt.ylabel('Customers')
plt.show()

# %%
top_customers = df.groupby('Customer ID')['Total Purchase Amount'].sum().sort_values(ascending=False)

top_customers.head(10)
# Out:
# Customer ID
# 39895    50659
# 39717    50496
# 48382    50179
# 6633     48499
# 49743    47015
# 22821    46939
# 24468    46683
# 13805    46567
# 539      46390
# 19960    46255
# Name: Total Purchase Amount, dtype: int64

# %%
top_customers.head(10).plot(kind='bar')
plt.title('Top 10 Customers by Spending')
plt.xlabel('Customer ID')
plt.ylabel('Total Purchase Amount')
plt.show()
